# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadullahLaskar/AhmadullahLaskar/blob/main/BookTrackingScrapy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downloading scrapy-2.13.3-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: cryptography>=37.0.0 in /usr/local/lib/python3.11/dist-packages (from scrapy) (43.0.3)
# Collecting cssselect>=0.9.1 (from scrapy)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from scrapy) (0.7.1)
# Collecting itemadapter>=0.1.0 (from scrapy)
#   Downloading itemadapter-0.11.0-py3-none-any.whl.metadata (18 kB)
# Collecting itemloaders>=1.0.1 (from scrapy)
#   Downloading itemloaders-1.3.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: lxml>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from scrapy) (5.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from scrapy) (24.2)
# Collecting parsel>=1.5.0 (from scrapy)
#   Downloading parsel-1.10.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting protego>=0.1.15 (from scrapy)
#   Downloading protego-0.5.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting pydispatcher>=2.0.5 (from scrapy)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pyopenssl>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from scrapy) (24.2.1)
# Collecting queuelib>=1.4.2 (from scrapy)
#   Downloading queuelib-1.8.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting service-identity>=18.1.0 (from scrapy)
#   Downloading service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tldextract (from scrapy)
#   Downloading tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting twisted>=21.7.0 (from scrapy)
#   Downloading twisted-25.5.0-py3-none-any.whl.metadata (22 kB)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading w3lib-2.3.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting zope-interface>=5.1.0 (from scrapy)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=37.0.0->scrapy) (1.17.1)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->scrapy) (25.3.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->scrapy) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->scrapy) (0.4.2)
# Collecting automat>=24.8.0 (from twisted>=21.7.0->scrapy)
#   Downloading automat-25.4.16-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from twisted>=21.7.0->scrapy)
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting hyperlink>=17.1.1 (from twisted>=21.7.0->scrapy)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting incremental>=24.7.0 (from twisted>=21.7.0->scrapy)
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from twisted>=21.7.0->scrapy) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zope-interface>=5.1.0->scrapy) (75.2.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from tldextract->scrapy) (3.10)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from tldextract->scrapy) (2.32.3)
# Collecting requests-file>=1.4 (from tldextract->scrapy)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from tldextract->scrapy) (3.18.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=37.0.0->scrapy) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2025.7.9)
# Downloading scrapy-2.13.3-py3-none-any.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 8.7 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading itemadapter-0.11.0-py3-none-any.whl (11 kB)
# Downloading itemloaders-1.3.2-py3-none-any.whl (12 kB)
# Downloading parsel-1.10.0-py2.py3-none-any.whl (17 kB)
# Downloading protego-0.5.0-py3-none-any.whl (10 kB)
# Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Downloading queuelib-1.8.0-py3-none-any.whl (13 kB)
# Downloading service_identity-24.2.0-py3-none-any.whl (11 kB)
# Downloading twisted-25.5.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 53.2 MB/s eta 0:00:00
# Downloading w3lib-2.3.1-py3-none-any.whl (21 kB)
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 14.7 MB/s eta 0:00:00
# Downloading tldextract-5.3.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 6.9 MB/s eta 0:00:00
# Downloading automat-25.4.16-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.5 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 5.1 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Installing collected packages: pydispatcher, zope-interface, w3lib, queuelib, protego, jmespath, itemadapter, incremental, hyperlink, cssselect, constantly, automat, twisted, requests-file, parsel, tldextract, service-identity, itemloaders, scrapy
# Successfully installed automat-25.4.16 constantly-23.10.4 cssselect-1.3.0 hyperlink-21.0.0 incremental-24.7.2 itemadapter-0.11.0 itemloaders-1.3.2 jmespath-1.0.1 parsel-1.10.0 protego-0.5.0 pydispatcher-2.0.7 queuelib-1.8.0 requests-file-2.1.0 scrapy-2.13.3 service-identity-24.2.0 tldextract-5.3.0 twisted-25.5.0 w3lib-2.3.1 zope-interface-7.2

# %%
import scrapy

class BooksSpider(scrapy.Spider):
    name = 'books'
    start_urls = ['http://books.toscrape.com/']

    def parse(self, response):
        for book in response.css('article.product_pod'):
            yield {
                'title': book.css('h3 a::attr(title)').get(),
                'price': book.css('.price_color::text').get(),
                'availability': book.css('.availability::text').getall()[-1].strip()
            }

# %%
spider_code = """
import scrapy

class BooksSpider(scrapy.Spider):
    name = 'books'
    start_urls = ['http://books.toscrape.com/']

    def parse(self, response):
        for book in response.css('article.product_pod'):
            yield {
                'title': book.css('h3 a::attr(title)').get(),
                'price': book.css('.price_color::text').get(),
                'availability': book.css('.availability::text').getall()[-1].strip()
            }
"""

with open("books_spider.py", "w") as f:
    f.write(spider_code)

# %%
# !scrapy startproject books_project
# Out:
# New Scrapy project 'books_project', using template directory '/usr/local/lib/python3.11/dist-packages/scrapy/templates/project', created in:
#     /content/books_project
#
# You can start your first spider with:
#     cd books_project
#     scrapy genspider example example.com

# %%
# !mv books_spider.py books_project/books_project/spiders/

# %%
import os
os.chdir("books_project")

# !scrapy crawl books -o books.csv
# Out:
# 2025-07-14 08:47:35 [scrapy.utils.log] INFO: Scrapy 2.13.3 started (bot: books_project)
# 2025-07-14 08:47:35 [scrapy.utils.log] INFO: Versions:
# {'lxml': '5.4.0',
#  'libxml2': '2.13.8',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]',
#  'pyOpenSSL': '24.2.1 (OpenSSL 3.3.2 3 Sep 2024)',
#  'cryptography': '43.0.3',
#  'Platform': 'Linux-6.1.123+-x86_64-with-glibc2.35'}
# 2025-07-14 08:47:35 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-07-14 08:47:35 [asyncio] DEBUG: Using selector: EpollSelector
# 2025-07-14 08:47:35 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-07-14 08:47:35 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2025-07-14 08:47:35 [scrapy.extensions.telnet] INFO: Telnet Password: 7f994ccee09fc365
# 2025-07-14 08:47:35 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-07-14 08:47:35 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'books_project',
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 1,
#  'DOWNLOAD_DELAY': 1,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'books_project.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['books_project.spiders']}
# 2025-07-14 08:47:35 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-07-14 08:47:35 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-07-14 08:47:35 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-07-14 08:47:35 [scrapy.core.engine] INFO: Spider opened
# 2025-07-14 08:47:35 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-07-14 08:47:35 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-07-14 08:47:35 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://books.toscrape.com/robots.txt> (referer: None)
# 2025-07-14 08:47:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/> (referer: None)
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'A Light in the Attic', 'price': '£51.77', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Tipping the Velvet', 'price': '£53.74', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Soumission', 'price': '£50.10', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Sharp Objects', 'price': '£47.82', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Sapiens: A Brief History of Humankind', 'price': '£54.23', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Requiem Red', 'price': '£22.65', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Dirty Little Secrets of Getting Your Dream Job', 'price': '£33.34', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'price': '£17.93', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'price': '£22.60', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Black Maria', 'price': '£52.15', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'price': '£13.99', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': "Shakespeare's Sonnets", 'price': '£20.66', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Set Me Free', 'price': '£17.46', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'price': '£52.29', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Rip it Up and Start Again', 'price': '£35.02', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'price': '£57.25', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Olio', 'price': '£23.88', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'price': '£37.59', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Libertarianism for Beginners', 'price': '£51.33', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': "It's Only the Himalayas", 'price': '£45.17', 'availability': 'In stock'}
# 2025-07-14 08:47:36 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-07-14 08:47:36 [scrapy.extensions.feedexport] INFO: Stored csv feed (20 items) in: books.csv
# 2025-07-14 08:47:36 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 460,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 51751,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 1.518498,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 7, 14, 8, 47, 36, 929652, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 20,
#  'items_per_minute': 1200.0,
#  'log_count/DEBUG': 25,
#  'log_count/INFO': 11,
#  'memusage/max': 137613312,
#  'memusage/startup': 137613312,
#  'response_received_count': 2,
#  'responses_per_minute': 120.0,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 7, 14, 8, 47, 35, 411154, tzinfo=datetime.timezone.utc)}
# 2025-07-14 08:47:36 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd

df = pd.read_csv("books.csv")
df.head()
# Out:
#                                    title   price availability
# 0                   A Light in the Attic  £51.77     In stock
# 1                     Tipping the Velvet  £53.74     In stock
# 2                             Soumission  £50.10     In stock
# 3                          Sharp Objects  £47.82     In stock
# 4  Sapiens: A Brief History of Humankind  £54.23     In stock
